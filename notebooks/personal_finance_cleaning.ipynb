# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.0 MB 1.6 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/10.0 MB 1.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/10.0 MB 1.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/10.0 MB 1.3 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/10.0 MB 1.2 MB/s eta 0:00:08
#    ------- -------------------------------- 1.8/10.0 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/10.0 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/10.0 MB 1.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.6/10.0 MB 1.2 MB/s eta 0:00:06
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('D:/clg_project/AI-Financial-Wellness-Coach/data/raw/raw/Personal_Finance_Dataset.csv')

# %%
df.shape
# Out:
# (1500, 5)

# %%
df.columns
# Out:
# Index(['Date', 'Transaction Description', 'Category', 'Amount', 'Type'], dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     1500 non-null   str
#  1   Transaction Description  1500 non-null   str
#  2   Category                 1500 non-null   str
#  3   Amount                   1500 non-null   float64
#  4   Type                     1500 non-null   str
# dtypes: float64(1), str(4)
# memory usage: 58.7 KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Date                   Transaction Description       Category  \
# 0     2020-01-02                               Score each.   Food & Drink
# 1     2020-01-02                       Quality throughout.      Utilities
# 2     2020-01-04        Instead ahead despite measure ago.           Rent
# 3     2020-01-05  Information last everything thank serve.     Investment
# 4     2020-01-13              Future choice whatever from.   Food & Drink
# ...          ...                                       ...            ...
# 1495  2024-12-28                            Quite as when.           Rent
# 1496  2024-12-28                   Right analysis mention.  Entertainment
# 1497  2024-12-28                    No couple debate must.     Investment
# 1498  2024-12-29                  Discussion black follow.       Shopping
# 1499  2024-12-29         Pressure activity defense detail.          Other
#
#        Amount     Type
# ...

# %%
df.head(10)
# Out:
#         Date                    Transaction Description       Category  \
# 0 2020-01-02                                Score each.   Food & Drink
# 1 2020-01-02                        Quality throughout.      Utilities
# 2 2020-01-04         Instead ahead despite measure ago.           Rent
# 3 2020-01-05   Information last everything thank serve.     Investment
# 4 2020-01-13               Future choice whatever from.   Food & Drink
# 5 2020-01-14             Benefit suggest page southern.       Shopping
# 6 2020-01-18                      By two bad fall pick.   Food & Drink
# 7 2020-01-19  Court attorney product significant world.          Other
# 8 2020-01-21                               Herself law.  Entertainment
# 9 2020-01-25                   Have decide environment.           Rent
#
#     Amount     Type
# 0  1485.69  Expense
# 1  1475.58  Expense
# 2  1185.08  Expense
# 3  2291.00   Income
# 4  1126.88  Expense
# 5   448.68  Expense
# 6  1520.03  Expense
# ...

# %%
df.isna().sum()
# Out:
# Date                       0
# Transaction Description    0
# Category                   0
# Amount                     0
# Type                       0
# dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Category'].unique()
# Out:
# <StringArray>
# [    'Food & Drink',        'Utilities',             'Rent',
#        'Investment',         'Shopping',            'Other',
#     'Entertainment', 'Health & Fitness',           'Salary',
#            'Travel']
# Length: 10, dtype: str

# %%
df[df['Category'] == "Food & Drink"]
# Out:
#            Date                        Transaction Description      Category  \
# 0    2020-01-02                                    Score each.  Food & Drink
# 4    2020-01-13                   Future choice whatever from.  Food & Drink
# 6    2020-01-18                          By two bad fall pick.  Food & Drink
# 14   2020-01-31                          How trip learn enter.  Food & Drink
# 23   2020-02-08                            Around there water.  Food & Drink
# ...         ...                                            ...           ...
# 1429 2024-10-07                        Hundred step according.  Food & Drink
# 1430 2024-10-08                                   Group never.  Food & Drink
# 1451 2024-11-03                    Doctor population grow bar.  Food & Drink
# 1467 2024-11-18                       Board notice later thus.  Food & Drink
# 1491 2024-12-19  Democratic recent student specific political.  Food & Drink
#
#        Amount     Type
# ...

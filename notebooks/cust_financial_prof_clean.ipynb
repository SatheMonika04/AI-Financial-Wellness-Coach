# %%
import pandas as pd

# %%
df = pd.read_csv('D:/clg_project/AI-Financial-Wellness-Coach/data/raw/main_data/Customer_financial_profiles.csv')

# %%
df.head()
# Out:
#    id  current_age  birth_year  birth_month  gender  \
# 0   1           64        1961            3  Female
# 1   2           39        1986           12  Female
# 2   3           50        1975            7  Female
# 3   4           27        1998            2    Male
# 4   5           45        1980            7   Other
#
#                                        address  per_capita_income  \
# 0  Street 286, Indore, Madhya Pradesh - 452645              86125
# 1    Street 268, Kolkata, West Bengal - 700555              68414
# 2  Street 262, Lucknow, Uttar Pradesh - 226797              22595
# 3     Street 265, Nagpur, Maharashtra - 440623              24158
# 4            Street 157, Delhi, Delhi - 110965              45475
#
#    yearly_income  total_debt  credit_score  ...  transaction_id        date  \
# 0        1033501      280435           715  ...            1251  2024-03-28
# 1         820965           0           834  ...            9976  2025-09-20
# ...

# %%
df.shape
# Out:
# (20000, 21)

# %%
df.columns
# Out:
# Index(['id', 'current_age', 'birth_year', 'birth_month', 'gender', 'address',
#        'per_capita_income', 'yearly_income', 'total_debt', 'credit_score',
#        'num_credit_cards', 'transaction_id', 'date', 'client_id', 'card_id',
#        'amount', 'use_chip', 'merchant_id', 'merchant_city', 'merchant_state',
#        'zip'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 20000 non-null  int64
#  1   current_age        20000 non-null  int64
#  2   birth_year         20000 non-null  int64
#  3   birth_month        20000 non-null  int64
#  4   gender             20000 non-null  object
#  5   address            20000 non-null  object
#  6   per_capita_income  20000 non-null  int64
#  7   yearly_income      20000 non-null  int64
#  8   total_debt         20000 non-null  int64
#  9   credit_score       20000 non-null  int64
#  10  num_credit_cards   20000 non-null  int64
#  11  transaction_id     20000 non-null  int64
#  12  date               20000 non-null  object
#  13  client_id          20000 non-null  object
#  14  card_id            20000 non-null  object
#  15  amount             20000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  id   current_age    birth_year   birth_month  \
# count  20000.000000  20000.000000  20000.000000  20000.000000
# mean   10000.500000     44.210100   1980.789900      6.479150
# std     5773.647028     14.992515     14.992515      3.459532
# min        1.000000     19.000000   1955.000000      1.000000
# 25%     5000.750000     31.000000   1968.000000      3.000000
# 50%    10000.500000     44.000000   1981.000000      7.000000
# 75%    15000.250000     57.000000   1994.000000     10.000000
# max    20000.000000     70.000000   2006.000000     12.000000
#
#        per_capita_income  yearly_income    total_debt  credit_score  \
# count       20000.000000   2.000000e+04  2.000000e+04  20000.000000
# mean        61234.419700   7.348131e+05  1.345380e+05    702.979750
# std         35354.273099   4.242512e+05  1.739757e+05     76.993944
# min         12500.000000   1.500000e+05  0.000000e+00    421.000000
# ...

# %%
df.describe(include="object")
# Out:
#        gender                                     address        date  \
# count   20000                                       20000       20000
# unique      3                                        4938        1035
# top      Male  Street 11, Lucknow, Uttar Pradesh - 226280  2024-01-22
# freq     9855                                          22          34
#
#           client_id    card_id use_chip merchant_id merchant_city  \
# count         20000      20000    20000       20000         20000
# unique         4941      10030        2         500            15
# top     CLTIND00062  CRD029871      Yes    MCH00471         Surat
# freq             22          7    13927          63          1761
#
#        merchant_state
# count           20000
# unique             11
# top       Maharashtra
# freq             4132

# %%
df.isnull().sum()
# Out:
# id                   0
# current_age          0
# birth_year           0
# birth_month          0
# gender               0
# address              0
# per_capita_income    0
# yearly_income        0
# total_debt           0
# credit_score         0
# num_credit_cards     0
# transaction_id       0
# date                 0
# client_id            0
# card_id              0
# amount               0
# use_chip             0
# merchant_id          0
# merchant_city        0
# merchant_state       0
# zip                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

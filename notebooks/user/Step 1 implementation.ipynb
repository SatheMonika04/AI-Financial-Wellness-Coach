# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# File paths
INPUT_FILE = Path("../../data/master/final_master_transaction.csv")
OUTPUT_DIR = Path("../../data/master")

# Load data
df = pd.read_csv(INPUT_FILE)

print("Dataset shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Dataset shape: (7000, 20)
#
# Columns:
# ['transaction_id', 'transaction_date', 'transaction_time', 'merchant', 'description', 'amount', 'currency', 'payment_method', 'transaction_type', 'category', 'city', 'state', 'country', 'day', 'week', 'month', 'weekend', 'month_end', 'salary_week', 'festival_season']

# %%
# Data Verification
print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nDuplicate transaction IDs:")
print(df["transaction_id"].duplicated().sum())

print("\nTransaction types:")
print(df["transaction_type"].value_counts())

print("\nCategories:")
print(df["category"].value_counts())

print("\nCurrencies:")
print(df["currency"].value_counts())

print("\nCities:")
print(df["city"].nunique())
print(df["city"].unique())
# Out:
# Rows: 7000
# Columns: 20
#
# Duplicate transaction IDs:
# 0
#
# Transaction types:
# transaction_type
# Debit     6810
# Credit     190
# Name: count, dtype: int64
#
# Categories:
# category
# Bills            2059
# Food             1328
# Groceries         912
# Shopping          550
# Other             435
# Fuel              423
# Miscellaneous     358
# Subscription      242
# Salary            173
# Entertainment     167
# Rent              165
# Insurance         152
# Investment         36
# Name: count, dtype: int64
#
# Currencies:
# currency
# INR    7000
# Name: count, dtype: int64
#
# Cities:
# 15
# ['Bengaluru' 'Indore' 'Pune' 'Surat' 'Nagpur' 'Lucknow' 'Ahmedabad'
#  'Chennai' 'Noida' 'Jaipur' 'Hyderabad' 'Mumbai' 'Delhi' 'Kochi' 'Kolkata']

# %%
# Creating synthetic user data 
N_USERS = 50

user_ids = [
    f"U{i:04d}"
    for i in range(1, N_USERS + 1)
]

print(user_ids[:10])
print(user_ids[-5:])
print("Total users:", len(user_ids))
# Out:
# ['U0001', 'U0002', 'U0003', 'U0004', 'U0005', 'U0006', 'U0007', 'U0008', 'U0009', 'U0010']
# ['U0046', 'U0047', 'U0048', 'U0049', 'U0050']
# Total users: 50
